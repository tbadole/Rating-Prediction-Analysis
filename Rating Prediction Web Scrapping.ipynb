# %%
# Importing Libraries/Dependencies
import selenium
import pandas as pd
import time
import requests
from selenium import webdriver
from  bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import StaleElementReferenceException

# %% [markdown]
# # Scraping Reviews from https://www.flipkart.com/

# %%
# Connecting to the webdriver 
driver = webdriver.Chrome("chromedriver.exe")
driver.maximize_window()        # Maximizing the window
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_6160/1597520620.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("chromedriver.exe")

# %%
# Getting the webpage of mentioned url
url = "https://www.flipkart.com/"
driver.get(url)
time.sleep(2)
# Clicking on cancel button 
driver.find_element_by_xpath("//div[@class='_2QfC02']/button").click()
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_6160/2220416176.py:6: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath("//div[@class='_2QfC02']/button").click()

# %%
# Listing down the items that need to be searched
srch_items = ['laptops', 'Phones','smart watches','Monitors']

# %%
# Creating empty lists to fetch required data
title = []           # Title of the product
review_text = []     # Text of the review or comments of the particular product
ratings = []         # Rating of the product

# %%
# Defining function to scrap the required data of products
def scrap():    
        for i in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
            review_text.append(i.text)
        for i in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
            title.append(i.text)
        for i in driver.find_elements_by_xpath("//p[@class='_2-N8zT']/../div"):
            ratings.append(i.text)
        return

# %%
# Creating empty list to fetch the page URLs of the products
urls=[]

# %%
for i in srch_items:
    # Find search bar
    srchBar = driver.find_element_by_xpath("//div[@class='_3OO5Xc']/input")
    srchBar.clear()
    srchBar.send_keys(i)
    # Clicking on search button
    driver.find_element_by_xpath("//button[@class='L0Z3Pu']").click()
    time.sleep(3)
    page = []
    for i in driver.find_elements_by_xpath("//nav[@class='yFHi8N']/a"):
        page.append(i.get_attribute('href'))
    for i in page[0:4]:
        driver.get(i)
        time.sleep(3)
        items = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
        for i in items:
            urls.append(i.get_attribute('href'))
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_6160/2655272402.py:3: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   srchBar = driver.find_element_by_xpath("//div[@class='_3OO5Xc']/input")
# C:\Users\Admin\AppData\Local\Temp/ipykernel_6160/2655272402.py:7: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath("//button[@class='L0Z3Pu']").click()
# C:\Users\Admin\AppData\Local\Temp/ipykernel_6160/2655272402.py:10: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//nav[@class='yFHi8N']/a"):
# C:\Users\Admin\AppData\Local\Temp/ipykernel_6160/2655272402.py:15: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   items = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")

# %%
# Checking the length of the url
len(urls)
# Out:
# 384

# %%
# Fetching the required data from the website
for i in urls:
    driver.get(i)
    time.sleep(2)
    for _ in range(2):
        driver.execute_script("window.scrollBy(0,6000)")
        time.sleep(1)
        # Clicking on all reviews
    try:
        btn=driver.find_element_by_xpath("//div[@class='_2c2kV-']/following::a")
        lnk = btn.get_attribute('href')
        driver.get(lnk)
        time.sleep(1)
    except NoSuchElementException:
        pass
    
# Calling the function
    scrap()        
    try:
        n_page=driver.find_elements_by_xpath("//nav[@class='yFHi8N']/a")
        np=[]
        for i in n_page:
            np.append(i.get_attribute('href'))
        for i in np[0:18]:
            driver.get(i)
            time.sleep(1)
            scrap()
    except: continue
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_6160/2219023809.py:10: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   btn=driver.find_element_by_xpath("//div[@class='_2c2kV-']/following::a")
# C:\Users\Admin\AppData\Local\Temp/ipykernel_6160/1712153909.py:3: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
# C:\Users\Admin\AppData\Local\Temp/ipykernel_6160/1712153909.py:5: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
# C:\Users\Admin\AppData\Local\Temp/ipykernel_6160/1712153909.py:7: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//p[@class='_2-N8zT']/../div"):
# C:\Users\Admin\AppData\Local\Temp/ipykernel_6160/2219023809.py:20: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   n_page=driver.find_elements_by_xpath("//nav[@class='yFHi8N']/a")

# %%
# Checking the length of the columns
len(ratings), len(review_text), len(title)
# Out:
# (29297, 29297, 29297)

# %%
# Creating the dataframe for scraped data from the flipkart website
data = list(zip(title,review_text,ratings))
df2 = pd.DataFrame(data, columns = ["Review_title","Reiew_text","Ratings"])
df2
# Out:
#             Review_title                                         Reiew_text  \
# 0              Excellent  One of the best student laptop under 50000 .Fo...
# 1              Wonderful  I got my laptop delivered and this is a solid ...
# 2        Value-for-money  Very good product and awesome and perfect qual...
# 3      Terrific purchase  Awesome performance. Amd ryzen 5 and amd graph...
# 4         Simply awesome  Classic and elegant design !! Fast and respons...
# ...                  ...                                                ...
# 29292    Value-for-money                             Good screen quality...
# 29293          Wonderful  Cool and best in below 9000 prize range ,go fo...
# 29294          Brilliant  Product is very nice and deisplay too good. I ...
# 29295        Bad quality  For day long work go for Dell ... MSI is just ...
# 29296          Excellent                                    Too softly ☺️☺️
#
#       Ratings
# 0           5
# 1           4
# 2           4
# 3           5
# 4           5
# ...       ...
# 29292       4
# 29293       5
# 29294       5
# 29295       2
# 29296       5
#
# [29297 rows x 3 columns]

# %%
# Saving the scraped data into csv file
df2.to_csv("Flipkrt_reviews.csv")

# %%
driver.close()

# %% [markdown]
# # Scraping Reviews from https://www.amazon.in/

# %%
# Connecting to the webdriver 
driver = webdriver.Chrome("chromedriver.exe")
driver.maximize_window()        # Maximizing the window
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_6160/1597520620.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("chromedriver.exe")

# %%
# Getting the webpage of mentioned url
url = "https://www.amazon.in/"
driver.get(url)
time.sleep(3)

# %%
# Listing down the items that need to be searched
srch_items = ['laptops','phones','headphones','smart watches', 'Professional Cameras', 'Printers', 'Monitors', 'Home theater', 'Router']

# %%
# Creating empty lists to fetch required data
title = []           # Title of the product
review_text = []     # Text of the review or comments of the particular product
ratings = []         # Rating of the product

# %%
# Fetching the required data from the website
for i in srch_items:
    srchbar = driver.find_element_by_id("twotabsearchtextbox")
    srchbar.send_keys(i)
    driver.find_element_by_id("nav-search-submit-button").click()  # Clicking on search button
    time.sleep(1)
    item_url = []
    for i in driver.find_elements_by_xpath("//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-2']/a"):
        item_url.append(i.get_attribute('href'))
    for i in item_url:
        driver.get(i)
        time.sleep(1)
        for _ in range(2):
            driver.execute_script("window.scrollBy(0,6000)")
            time.sleep(1)
        # Clicking on see all reviews
        try:
            driver.find_element_by_xpath("//a[@class='a-link-emphasis a-text-bold']").click()
        except:
            pass
        
        url_ = []
        try:
            two_str = driver.find_element_by_xpath("//table[@id='histogramTable']/tbody/tr[4]/td[2]/a")
            url_.append(two_str.get_attribute('href'))
        except: pass
        try:
            three_str = driver.find_element_by_xpath("//table[@id='histogramTable']/tbody/tr[3]/td[2]/a")
            url_.append(three_str.get_attribute('href'))
        except: pass
        try:
            one_str = driver.find_element_by_xpath("//table[@id='histogramTable']/tbody/tr[5]/td[2]/a")
            url_.append(one_str.get_attribute('href'))
        except: pass
        try:
            fiv_str = driver.find_element_by_xpath("//table[@id='histogramTable']/tbody/tr[1]/td[2]/a")
            url_.append(fiv_str.get_attribute('href'))
        except: pass
        try:
            four_str = driver.find_element_by_xpath("//table[@id='histogramTable']/tbody/tr[2]/td[2]/a")
            url_.append(four_str.get_attribute('href'))
        except: pass
        
        for i in url_:
            driver.get(i)
            time.sleep(1)
            for i in range(10):
                ids = driver.find_elements_by_xpath("//div[@class='a-section a-spacing-none review-views celwidget']/div")
                comment_ids = []
                for i in ids:
                    comment_ids.append(i.get_attribute('id'))

                for x in comment_ids:
                    # Extract user ids from each user on a page
                    try:
                        review_title = driver.find_element_by_xpath('//*[@id="' + x +'"]/div/div/div[2]/a[2]/span[1]')
                        title.append(review_title.get_attribute("innerHTML"))
                    except NoSuchElementException:
                        title.append('')

                    try:
                        rating = driver.find_element_by_xpath('//*[@id="' + x +'"]/div/div/div[2]/a[1]/i/span[1]')
                        ratings.append(rating.get_attribute("innerHTML"))
                    except NoSuchElementException:
                        ratings.append('')

                    try:
                        text = driver.find_element_by_xpath('//*[@id="' + x +'"]/div/div/div[4]/span/span')
                        review_text.append(text.get_attribute("innerHTML"))
                    except NoSuchElementException:
                        review_text.append('')
                try:
                    driver.find_element_by_xpath("//ul[@class='a-pagination']/li[2]/a").click()
                    time.sleep(3)
                except : break
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_6160/1750007599.py:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   srchbar = driver.find_element_by_id("twotabsearchtextbox")
# C:\Users\Admin\AppData\Local\Temp/ipykernel_6160/1750007599.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id("nav-search-submit-button").click()  # Clicking on search button
# C:\Users\Admin\AppData\Local\Temp/ipykernel_6160/1750007599.py:8: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-2']/a"):
# C:\Users\Admin\AppData\Local\Temp/ipykernel_6160/1750007599.py:18: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath("//a[@class='a-link-emphasis a-text-bold']").click()
# C:\Users\Admin\AppData\Local\Temp/ipykernel_6160/1750007599.py:24: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   two_str = driver.find_element_by_xpath("//table[@id='histogramTable']/tbody/tr[4]/td[2]/a")
# C:\Users\Admin\AppData\Local\Temp/ipykernel_6160/1750007599.py:28: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   three_str = driver.find_element_by_xpath("//table[@id='histogramTable']/tbody/tr[3]/td[2]/a")
# C:\Users\Admin\AppData\Local\Temp/ipykernel_6160/1750007599.py:32: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   one_str = driver.find_element_by_xpath("//table[@id='histogramTable']/tbody/tr[5]/td[2]/a")
# C:\Users\Admin\AppData\Local\Temp/ipykernel_6160/1750007599.py:36: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   fiv_str = driver.find_element_by_xpath("//table[@id='histogramTable']/tbody/tr[1]/td[2]/a")
# C:\Users\Admin\AppData\Local\Temp/ipykernel_6160/1750007599.py:40: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   four_str = driver.find_element_by_xpath("//table[@id='histogramTable']/tbody/tr[2]/td[2]/a")
# C:\Users\Admin\AppData\Local\Temp/ipykernel_6160/1750007599.py:48: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   ids = driver.find_elements_by_xpath("//div[@class='a-section a-spacing-none review-views celwidget']/div")
# C:\Users\Admin\AppData\Local\Temp/ipykernel_6160/1750007599.py:56: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   review_title = driver.find_element_by_xpath('//*[@id="' + x +'"]/div/div/div[2]/a[2]/span[1]')
# C:\Users\Admin\AppData\Local\Temp/ipykernel_6160/1750007599.py:62: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   rating = driver.find_element_by_xpath('//*[@id="' + x +'"]/div/div/div[2]/a[1]/i/span[1]')
# C:\Users\Admin\AppData\Local\Temp/ipykernel_6160/1750007599.py:68: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   text = driver.find_element_by_xpath('//*[@id="' + x +'"]/div/div/div[4]/span/span')
# C:\Users\Admin\AppData\Local\Temp/ipykernel_6160/1750007599.py:73: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath("//ul[@class='a-pagination']/li[2]/a").click()
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6160/1750007599.py in <module>
#      49                 comment_ids = []
#      50                 for i in ids:
# ---> 51                     comment_ids.append(i.get_attribute('id'))
#      52
#      53                 for x in comment_ids:
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in get_attribute(self, name)
#     153         """
#     154
# --> 155         attribute_value = self.parent.execute_script(
#     156             "return (%s).apply(null, arguments);" % getAttribute_js,
#     157             self, name)
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute_script(self, script, *args)
#     877         command = Command.W3C_EXECUTE_SCRIPT
#     878
# --> 879         return self.execute(command, {
#     880             'script': script,
#     881             'args': converted_args})['value']
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     423         response = self.command_executor.execute(driver_command, params)
#     424         if response:
# --> 425             self.error_handler.check_response(response)
#     426             response['value'] = self._unwrap_value(
#     427                 response.get('value', None))
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=104.0.5112.82)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x006F5FD3+2187219]
# 	Ordinal0 [0x0068E6D1+1763025]
# 	Ordinal0 [0x005A3E78+802424]
# 	Ordinal0 [0x005A6854+813140]
# 	Ordinal0 [0x005A6712+812818]
# 	Ordinal0 [0x005A708A+815242]
# 	Ordinal0 [0x005FD9F9+1169913]
# 	Ordinal0 [0x005ECB8C+1100684]
# 	Ordinal0 [0x005FCFC2+1167298]
# 	Ordinal0 [0x005EC9A6+1100198]
# 	Ordinal0 [0x005C6F80+946048]
# 	Ordinal0 [0x005C7E76+949878]
# 	GetHandleVerifier [0x009990C2+2721218]
# 	GetHandleVerifier [0x0098AAF0+2662384]
# 	GetHandleVerifier [0x0078137A+526458]
# 	GetHandleVerifier [0x00780416+522518]
# 	Ordinal0 [0x00694EAB+1789611]
# 	Ordinal0 [0x006997A8+1808296]
# 	Ordinal0 [0x00699895+1808533]
# 	Ordinal0 [0x006A26C1+1844929]
# 	BaseThreadInitThunk [0x759BFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77557A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77557A6E+238]

# %%
len(ratings), len(title), len(review_text)
# Out:
# (75064, 75064, 75064)

# %%
#creating a dataframe
data = list(zip(title,review_text,ratings))
df = pd.DataFrame(data, columns = ["Review_title","Reiew_text","Ratings"])
df
# Out:
#                                             Review_title  \
# 0              worest battery backup and service support
# 1                           Battery was very bad bad bad
# 2                         Not buy this fan noise problem
# 3      Expected good battery life at its high price b...
# 4                               Battery very faster used
# ...                                                  ...
# 75059         Good Replacement and Meets my expectations
# 75060    Excellent Wifi Router for Fibre Option internet
# 75061  Good Signal for NETFLIX, PRIME VIDEO, etc. Goo...
# 75062                        Great but not yet for India
# 75063
#
#                                               Reiew_text             Ratings
# 0      battery backup was too worest .full charge dis...  2.0 out of 5 stars
# 1      Bad battery ,speed is okay ,battery is bad bad...  2.0 out of 5 stars
# 2      Two big problem in this laptop are<br>Fan nois...  2.0 out of 5 stars
# 3      Disappointed and it hanged in a span of 10 day...  3.0 out of 5 stars
# 4                                            No comments  3.0 out of 5 stars
# ...                                                  ...                 ...
# 75059  I purchased this Router to replace the Netgear...  4.0 out of 5 stars
# 75060  Excellent Speed, Easy to Install. I only wish ...  4.0 out of 5 stars
# 75061  Good Signal Strength and reach.  I get almost ...  4.0 out of 5 stars
# 75062  Great speed. Difficult and sometimes impossibl...  4.0 out of 5 stars
# 75063
#
# [75064 rows x 3 columns]

# %%
# Saving the data into csv file
df.to_csv("Amazon_reviews.csv")

# %%
# lets load the flipkart reviews file
flpkrt = pd.read_csv("Flipkrt_reviews.csv")
flpkrt
# Out:
#        Unnamed: 0       Review_title  \
# 0               0          Excellent
# 1               1          Wonderful
# 2               2    Value-for-money
# 3               3  Terrific purchase
# 4               4     Simply awesome
# ...           ...                ...
# 29292       29292    Value-for-money
# 29293       29293          Wonderful
# 29294       29294          Brilliant
# 29295       29295        Bad quality
# 29296       29296          Excellent
#
#                                               Reiew_text  Ratings
# 0      One of the best student laptop under 50000 .Fo...        5
# 1      I got my laptop delivered and this is a solid ...        4
# 2      Very good product and awesome and perfect qual...        4
# 3      Awesome performance. Amd ryzen 5 and amd graph...        5
# 4      Classic and elegant design !! Fast and respons...        5
# ...                                                  ...      ...
# 29292                             Good screen quality...        4
# 29293  Cool and best in below 9000 prize range ,go fo...        5
# 29294  Product is very nice and deisplay too good. I ...        5
# 29295  For day long work go for Dell ... MSI is just ...        2
# 29296                                    Too softly ☺️☺️        5
#
# [29297 rows x 4 columns]

# %%
# Concatenating the two datasets 
reviews = pd.concat([df, flpkrt],ignore_index=True)
reviews
# Out:
#                                              Review_title  \
# 0               worest battery backup and service support
# 1                            Battery was very bad bad bad
# 2                          Not buy this fan noise problem
# 3       Expected good battery life at its high price b...
# 4                                Battery very faster used
# ...                                                   ...
# 104356                                    Value-for-money
# 104357                                          Wonderful
# 104358                                          Brilliant
# 104359                                        Bad quality
# 104360                                          Excellent
#
#                                                Reiew_text             Ratings  \
# 0       battery backup was too worest .full charge dis...  2.0 out of 5 stars
# 1       Bad battery ,speed is okay ,battery is bad bad...  2.0 out of 5 stars
# 2       Two big problem in this laptop are<br>Fan nois...  2.0 out of 5 stars
# 3       Disappointed and it hanged in a span of 10 day...  3.0 out of 5 stars
# 4                                             No comments  3.0 out of 5 stars
# ...                                                   ...                 ...
# 104356                             Good screen quality...                   4
# 104357  Cool and best in below 9000 prize range ,go fo...                   5
# 104358  Product is very nice and deisplay too good. I ...                   5
# 104359  For day long work go for Dell ... MSI is just ...                   2
# 104360                                    Too softly ☺️☺️                   5
#
#         Unnamed: 0
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 104356     29292.0
# 104357     29293.0
# 104358     29294.0
# 104359     29295.0
# 104360     29296.0
#
# [104361 rows x 4 columns]

# %%
# Dropping unwanted column
reviews.drop(columns = 'Unnamed: 0', inplace=True)

# %%
# Displaying the merged dataset
reviews
# Out:
#                                              Review_title  \
# 0               worest battery backup and service support
# 1                            Battery was very bad bad bad
# 2                          Not buy this fan noise problem
# 3       Expected good battery life at its high price b...
# 4                                Battery very faster used
# ...                                                   ...
# 104356                                    Value-for-money
# 104357                                          Wonderful
# 104358                                          Brilliant
# 104359                                        Bad quality
# 104360                                          Excellent
#
#                                                Reiew_text             Ratings
# 0       battery backup was too worest .full charge dis...  2.0 out of 5 stars
# 1       Bad battery ,speed is okay ,battery is bad bad...  2.0 out of 5 stars
# 2       Two big problem in this laptop are<br>Fan nois...  2.0 out of 5 stars
# 3       Disappointed and it hanged in a span of 10 day...  3.0 out of 5 stars
# 4                                             No comments  3.0 out of 5 stars
# ...                                                   ...                 ...
# 104356                             Good screen quality...                   4
# 104357  Cool and best in below 9000 prize range ,go fo...                   5
# 104358  Product is very nice and deisplay too good. I ...                   5
# 104359  For day long work go for Dell ... MSI is just ...                   2
# 104360                                    Too softly ☺️☺️                   5
#
# [104361 rows x 3 columns]

# %%
# Saving the data into csv file
reviews.to_csv("Review_Rating.csv",index=False)

# %%
# Saving the data into excel file
reviews.to_excel("Review_Ratings.xlsx",index=False)

# %% [markdown]
# I have successfully scraped the required data from the websites flipcart.com and amazon.com. The dataframe consists of 101128 rows and 3 columns. And I have saved this dataframe in both excel and csv formats.
